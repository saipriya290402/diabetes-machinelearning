# %%
import numpy as np
import pandas as pd
df=pd.read_csv('kaggle_diabetes.csv')
df.shape
# Out:
# (2000, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# 1                        0.233   23        0
# 2                        0.630   31        1
# 3                        0.365   24        1
# 4                        0.536   21        0
# ...                        ...  ...      ...
# 1995                     0.370   33        0
# 1996                     0.719   36        1
# 1997                     0.382   42        0
# 1998                     0.319   26        1
# 1999                     0.547   25        0
#
# [2000 rows x 9 columns]>

# %%
df.head
# Out:
# <bound method NDFrame.head of       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# 1                        0.233   23        0
# 2                        0.630   31        1
# 3                        0.365   24        1
# 4                        0.536   21        0
# ...                        ...  ...      ...
# 1995                     0.370   33        0
# 1996                     0.719   36        1
# 1997                     0.382   42        0
# 1998                     0.319   26        1
# 1999                     0.547   25        0
#
# [2000 rows x 9 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns='Outcome')
y = df['Outcome']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
print('X_train size: {}, X_test size: {}'.format(X_train.shape, X_test.shape))
# Out:
# X_train size: (1600, 8), X_test size: (400, 8)

# %%
df.isnull()
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0           False    False          False          False    False  False
# 1           False    False          False          False    False  False
# 2           False    False          False          False    False  False
# 3           False    False          False          False    False  False
# 4           False    False          False          False    False  False
# ...           ...      ...            ...            ...      ...    ...
# 1995        False    False          False          False    False  False
# 1996        False    False          False          False    False  False
# 1997        False    False          False          False    False  False
# 1998        False    False          False          False    False  False
# 1999        False    False          False          False    False  False
#
#       DiabetesPedigreeFunction    Age  Outcome
# 0                        False  False    False
# 1                        False  False    False
# 2                        False  False    False
# 3                        False  False    False
# 4                        False  False    False
# ...                        ...    ...      ...
# 1995                     False  False    False
# 1996                     False  False    False
# 1997                     False  False    False
# 1998                     False  False    False
# 1999                     False  False    False
#
# [2000 rows x 9 columns]

# %%
correlation=X_train.corr()
correlation.style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_f3f25_row0_col0, #T_f3f25_row1_col1, #T_f3f25_row2_col2, #T_f3f25_row3_col3, #T_f3f25_row4_col4, #T_f3f25_row5_col5, #T_f3f25_row6_col6, #T_f3f25_row7_col7 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_f3f25_row0_col1 {
#   background-color: #804a09;
#   color: #f1f1f1;
# }
# #T_f3f25_row0_col2 {
#   background-color: #91560d;
#   color: #f1f1f1;
# }
# #T_f3f25_row0_col3 {
#   background-color: #714108;
#   color: #f1f1f1;
# }
# #T_f3f25_row0_col4 {
#   background-color: #5b3406;
#   color: #f1f1f1;
# }
# #T_f3f25_row0_col5, #T_f3f25_row0_col6, #T_f3f25_row3_col1, #T_f3f25_row3_col7, #T_f3f25_row4_col0, #T_f3f25_row6_col2, #T_f3f25_row7_col3, #T_f3f25_row7_col4 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_f3f25_row0_col7 {
#   background-color: #c7eae5;
#   color: #000000;
# }
# #T_f3f25_row1_col0, #T_f3f25_row5_col1 {
#   background-color: #b97b29;
#   color: #f1f1f1;
# }
# #T_f3f25_row1_col2 {
#   background-color: #874e0a;
#   color: #f1f1f1;
# }
# #T_f3f25_row1_col3 {
#   background-color: #a96c1e;
#   color: #f1f1f1;
# }
# #T_f3f25_row1_col4 {
#   background-color: #efdcad;
#   color: #000000;
# }
# #T_f3f25_row1_col5, #T_f3f25_row2_col0, #T_f3f25_row4_col5 {
#   background-color: #c38936;
#   color: #f1f1f1;
# }
# #T_f3f25_row1_col6 {
#   background-color: #9f6317;
#   color: #f1f1f1;
# }
# #T_f3f25_row1_col7, #T_f3f25_row2_col7 {
#   background-color: #e5cc8f;
#   color: #000000;
# }
# #T_f3f25_row2_col1, #T_f3f25_row5_col0 {
#   background-color: #844c09;
#   color: #f1f1f1;
# }
# #T_f3f25_row2_col3, #T_f3f25_row5_col4 {
#   background-color: #dcbc75;
#   color: #000000;
# }
# #T_f3f25_row2_col4 {
#   background-color: #b37625;
#   color: #f1f1f1;
# }
# #T_f3f25_row2_col5 {
#   background-color: #cea053;
#   color: #f1f1f1;
# }
# #T_f3f25_row2_col6 {
#   background-color: #794608;
#   color: #f1f1f1;
# }
# #T_f3f25_row3_col0 {
#   background-color: #583305;
#   color: #f1f1f1;
# }
# #T_f3f25_row3_col2 {
#   background-color: #ad7021;
#   color: #f1f1f1;
# }
# #T_f3f25_row3_col4 {
#   background-color: #f2f4f4;
#   color: #000000;
# }
# #T_f3f25_row3_col5 {
#   background-color: #f2e2b8;
#   color: #000000;
# }
# #T_f3f25_row3_col6 {
#   background-color: #bb7d2a;
#   color: #f1f1f1;
# }
# #T_f3f25_row4_col1 {
#   background-color: #d8b46c;
#   color: #000000;
# }
# #T_f3f25_row4_col2 {
#   background-color: #754308;
#   color: #f1f1f1;
# }
# #T_f3f25_row4_col3 {
#   background-color: #ebf3f2;
#   color: #000000;
# }
# #T_f3f25_row4_col6 {
#   background-color: #b77928;
#   color: #f1f1f1;
# }
# #T_f3f25_row4_col7 {
#   background-color: #663a07;
#   color: #f1f1f1;
# }
# #T_f3f25_row5_col2 {
#   background-color: #c79040;
#   color: #f1f1f1;
# }
# #T_f3f25_row5_col3 {
#   background-color: #f5f1e4;
#   color: #000000;
# }
# #T_f3f25_row5_col6, #T_f3f25_row6_col7 {
#   background-color: #9d6116;
#   color: #f1f1f1;
# }
# #T_f3f25_row5_col7 {
#   background-color: #a3671a;
#   color: #f1f1f1;
# }
# #T_f3f25_row6_col0, #T_f3f25_row7_col6 {
#   background-color: #6e4007;
#   color: #f1f1f1;
# }
# #T_f3f25_row6_col1 {
#   background-color: #7c4709;
#   color: #f1f1f1;
# }
# #T_f3f25_row6_col3 {
#   background-color: #d3aa5f;
#   color: #000000;
# }
# #T_f3f25_row6_col4 {
#   background-color: #ca9849;
#   color: #f1f1f1;
# }
# #T_f3f25_row6_col5 {
#   background-color: #894f0a;
#   color: #f1f1f1;
# }
# #T_f3f25_row7_col0 {
#   background-color: #d0ece8;
#   color: #000000;
# }
# #T_f3f25_row7_col1 {
#   background-color: #bf812d;
#   color: #f1f1f1;
# }
# #T_f3f25_row7_col2 {
#   background-color: #c08430;
#   color: #f1f1f1;
# }
# #T_f3f25_row7_col5 {
#   background-color: #5f3606;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f3f25_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Pregnancies</th>
#       <th class="col_heading level0 col1" >Glucose</th>
#       <th class="col_heading level0 col2" >BloodPressure</th>
#       <th class="col_heading level0 col3" >SkinThickness</th>
#       <th class="col_heading level0 col4" >Insulin</th>
#       <th class="col_heading level0 col5" >BMI</th>
#       <th class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th class="col_heading level0 col7" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3f25_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_f3f25_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f3f25_row0_col1" class="data row0 col1" >0.123721</td>
#       <td id="T_f3f25_row0_col2" class="data row0 col2" >0.150680</td>
#       <td id="T_f3f25_row0_col3" class="data row0 col3" >-0.067634</td>
#       <td id="T_f3f25_row0_col4" class="data row0 col4" >-0.079126</td>
#       <td id="T_f3f25_row0_col5" class="data row0 col5" >0.016572</td>
#       <td id="T_f3f25_row0_col6" class="data row0 col6" >-0.026252</td>
#       <td id="T_f3f25_row0_col7" class="data row0 col7" >0.546860</td>
#     </tr>
#     <tr>
#       <th id="T_f3f25_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_f3f25_row1_col0" class="data row1 col0" >0.123721</td>
#       <td id="T_f3f25_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f3f25_row1_col2" class="data row1 col2" >0.132851</td>
#       <td id="T_f3f25_row1_col3" class="data row1 col3" >0.047274</td>
#       <td id="T_f3f25_row1_col4" class="data row1 col4" >0.311833</td>
#       <td id="T_f3f25_row1_col5" class="data row1 col5" >0.227212</td>
#       <td id="T_f3f25_row1_col6" class="data row1 col6" >0.117238</td>
#       <td id="T_f3f25_row1_col7" class="data row1 col7" >0.240706</td>
#     </tr>
#     <tr>
#       <th id="T_f3f25_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_f3f25_row2_col0" class="data row2 col0" >0.150680</td>
#       <td id="T_f3f25_row2_col1" class="data row2 col1" >0.132851</td>
#       <td id="T_f3f25_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_f3f25_row2_col3" class="data row2 col3" >0.201592</td>
#       <td id="T_f3f25_row2_col4" class="data row2 col4" >0.099760</td>
#       <td id="T_f3f25_row2_col5" class="data row2 col5" >0.259239</td>
#       <td id="T_f3f25_row2_col6" class="data row2 col6" >0.043392</td>
#       <td id="T_f3f25_row2_col7" class="data row2 col7" >0.239267</td>
#     </tr>
#     <tr>
#       <th id="T_f3f25_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_f3f25_row3_col0" class="data row3 col0" >-0.067634</td>
#       <td id="T_f3f25_row3_col1" class="data row3 col1" >0.047274</td>
#       <td id="T_f3f25_row3_col2" class="data row3 col2" >0.201592</td>
#       <td id="T_f3f25_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f3f25_row3_col4" class="data row3 col4" >0.459391</td>
#       <td id="T_f3f25_row3_col5" class="data row3 col5" >0.395937</td>
#       <td id="T_f3f25_row3_col6" class="data row3 col6" >0.170719</td>
#       <td id="T_f3f25_row3_col7" class="data row3 col7" >-0.129198</td>
#     </tr>
#     <tr>
#       <th id="T_f3f25_level0_row4" class="row_heading level0 row4" >Insulin</th>
#       <td id="T_f3f25_row4_col0" class="data row4 col0" >-0.079126</td>
#       <td id="T_f3f25_row4_col1" class="data row4 col1" >0.311833</td>
#       <td id="T_f3f25_row4_col2" class="data row4 col2" >0.099760</td>
#       <td id="T_f3f25_row4_col3" class="data row4 col3" >0.459391</td>
#       <td id="T_f3f25_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_f3f25_row4_col5" class="data row4 col5" >0.225971</td>
#       <td id="T_f3f25_row4_col6" class="data row4 col6" >0.162963</td>
#       <td id="T_f3f25_row4_col7" class="data row4 col7" >-0.093389</td>
#     </tr>
#     <tr>
#       <th id="T_f3f25_level0_row5" class="row_heading level0 row5" >BMI</th>
#       <td id="T_f3f25_row5_col0" class="data row5 col0" >0.016572</td>
#       <td id="T_f3f25_row5_col1" class="data row5 col1" >0.227212</td>
#       <td id="T_f3f25_row5_col2" class="data row5 col2" >0.259239</td>
#       <td id="T_f3f25_row5_col3" class="data row5 col3" >0.395937</td>
#       <td id="T_f3f25_row5_col4" class="data row5 col4" >0.225971</td>
#       <td id="T_f3f25_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_f3f25_row5_col6" class="data row5 col6" >0.112391</td>
#       <td id="T_f3f25_row5_col7" c
